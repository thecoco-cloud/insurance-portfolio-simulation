# %%
import numpy as np
import pandas as pd

n_contracts = 10000
claim_probability = 0.05

claims = np.random.binomial(1, claim_probability, n_contracts)

print("Number of claims:", claims.sum())
# Out:
# Number of claims: 492
